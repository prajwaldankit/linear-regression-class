# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
salaries = pd.read_csv('dataset/Salary_dataset.csv')
salaries.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
plt.scatter(salaries.YearsExperience, salaries.Salary)
plt.show()

# %%
def loss_function(m, b, points):
    n = len(points)
    total_error = 0
    for i in range(n):
        x = points.iloc[i].YearsExperience
        y = points.iloc[i].Salary
        y_predicted = m * x + b
        total_error += (y - y_predicted) ** 2
    return total_error / n

# %%
loss_function(12328.431032152079, 3239.350283862494 ,salaries)
# Out:
# np.float64(132097129.31925529)

# %%
def gradient_descent(m_now, b_now, points, learning_rate = 0.01):
    m_gradient = 0
    b_gradient = 0
    n = len(points)
    for i in range(n):
        x = points.iloc[i].YearsExperience
        y = points.iloc[i].Salary
        y_predicted = m_now * x + b_now
        error = y-y_predicted
        m_gradient += -(2/n) * x * error
        b_gradient += -(2/n) * error

    m = m_now - learning_rate * m_gradient
    b = b_now - learning_rate * b_gradient

    return m , b

# %%
m = 0
b = 0
learning_rate = 0.01
epochs = 5000

for i in range(epochs):
    m,b = gradient_descent(m,b,salaries,learning_rate)

print(f"m = {m}, b = {b}")
# Out:
# m = 9449.96232529701, b = 24848.20394034611

# %%
plt.scatter(salaries.YearsExperience, salaries.Salary, color='blue')
plt.plot(list(range(0,12)), list(m * x + b for x in range(0,12)))
plt.show()

# %%
def optimized_gradient_descent(m_now, b_now, X, Y, learning_rate):
  
    n = len(X)
    y_predicted = m_now * X + b_now
    
    error = Y - y_predicted

    m_gradient = (-2/n) * np.dot(X, error)
    b_gradient = -(2/n) * np.sum(error)

    m = m_now - learning_rate * m_gradient
    b = b_now - learning_rate * b_gradient

    return m , b

# %%
m = 0
b = 0
learning_rate = 0.01
epochs = 5000
x = salaries.YearsExperience.values
y = salaries.Salary.values

for i in range(epochs):
    m,b = optimized_gradient_descent(m,b,x, y,learning_rate)

plt.scatter(salaries.YearsExperience, salaries.Salary, color='blue')
plt.plot(list(range(0,12)), list(m * x + b for x in range(0,12)))
plt.show()
